# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('dataset.csv')

# %%
dataset['country_txt'].value_counts()
# Out:
# Peru                        5986
# Colombia                    5545
# El Salvador                 5318
# United Kingdom              3995
# India                       2741
# Spain                       2722
# Turkey                      2326
# United States               2268
# Chile                       2263
# France                      2181
# Sri Lanka                   2055
# Guatemala                   2009
# Nicaragua                   1960
# Philippines                 1909
# South Africa                1854
# Lebanon                     1776
# Pakistan                    1594
# Italy                       1424
# Israel                       980
# West Bank and Gaza Strip     912
# Algeria                      878
# Argentina                    782
# Greece                       651
# Bangladesh                   548
# West Germany (FRG)           541
# Iran                         517
# Germany                      505
# Egypt                        456
# ...

# %%
dataset['country_txt'].value_counts().plot()

# %%
dataset['country_txt'].value_counts().plot('bar')

# %%
dataset.shape
# Out:
# (65499, 23)

# %%
dataset['region_txt'].value_counts()
# Out:
# South America                  15671
# Western Europe                 12937
# Central America & Caribbean    10172
# Middle East & North Africa      8449
# South Asia                      7087
# Sub-Saharan Africa              4077
# Southeast Asia                  2727
# North America                   2637
# Eastern Europe                   714
# East Asia                        577
# Central Asia                     257
# Australasia & Oceania            194
# Name: region_txt, dtype: int64

# %%
dataset['region_txt'].value_counts().plot('bar')

# %%
dataset['attacktype1_txt'].value_counts().plot('bar')
